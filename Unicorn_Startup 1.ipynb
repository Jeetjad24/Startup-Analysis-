# %%
import pandas as pd
import numpy as np 
import scipy.stats as stats

import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
from matplotlib.pyplot import figure
from plotly.offline import init_notebook_mode,iplot
import plotly.graph_objects as go

# %matplotlib inline

# %%
#Data set Import 
df = pd.read_csv("D:\\unicorns till sep 2022.csv", encoding='latin-1') 
df.head()
# Out:
#      Company Valuation ($B) Date Joined        Country         CityÂ   \
# 0  ByteDance           $140    4/7/2017          China        Beijing
# 1     SpaceX           $127   12/1/2012  United States      Hawthorne
# 2      SHEIN           $100    7/3/2018          China       Shenzhen
# 3     Stripe            $95   1/23/2014  United States  San Francisco
# 4      Canva            $40    1/8/2018      Australia    Surry Hills
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
# Cleaning the data
df=pd.DataFrame(df)
df.rename(columns = {'Date Joined' : 'Date'},inplace = True) 


date = df.Date.str.split('/',expand =True)
df['year']= date[2]
df['month']= date[0]

df.year=pd.to_numeric(df.year)

df.head(10)
# Out:
#         Company Valuation ($B)        Date         Country         CityÂ   \
# 0     ByteDance           $140    4/7/2017           China        Beijing
# 1        SpaceX           $127   12/1/2012   United States      Hawthorne
# 2         SHEIN           $100    7/3/2018           China       Shenzhen
# 3        Stripe            $95   1/23/2014   United States  San Francisco
# 4         Canva            $40    1/8/2018       Australia    Surry Hills
# 5  Checkout.com            $40    5/2/2019  United Kingdom         London
# 6     Instacart            $39  12/30/2014   United States  San Francisco
# 7    Databricks            $38    2/5/2019   United States  San Francisco
# 8       Revolut            $33   4/26/2018  United Kingdom         London
# 9    Epic Games         $31.50  10/26/2018   United States           Cary
#
#                               Industry  \
# 0              Artificial intelligence
# 1                                Other
# 2      E-commerce & direct-to-consumer
# 3                              Fintech
# 4         Internet software & services
# 5                              Fintech
# 6  Supply chain, logistics, & delivery
# 7          Data management & analytics
# 8                              Fintech
# 9                                Other
#
#                                            Investors  year month
# 0  Sequoia Capital China, SIG Asia Investments, S...  2017     4
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...  2012    12
# 2  Tiger Global Management, Sequoia Capital China...  2018     7
# 3        Khosla Ventures, LowercaseCapital, capitalG  2014     1
# 4  Sequoia Capital China, Blackbird Ventures, Mat...  2018     1
# 5  Tiger Global Management, Insight Partners, DST...  2019     5
# 6  Khosla Ventures, Kleiner Perkins Caufield & By...  2014    12
# 7  Andreessen Horowitz, New Enterprise Associates...  2019     2
# 8         index Ventures, DST Global, Ribbit Capital  2018     4
# 9              Tencent Holdings, KKR, Smash Ventures  2018    10

# %%
df.columns = df.columns.str.replace('Â', '')
df.rename(columns={'City ': 'City'}, inplace=True)
df.head()
# Out:
#      Company Valuation ($B)       Date        Country          City   \
# 0  ByteDance           $140   4/7/2017          China        Beijing
# 1     SpaceX           $127  12/1/2012  United States      Hawthorne
# 2      SHEIN           $100   7/3/2018          China       Shenzhen
# 3     Stripe            $95  1/23/2014  United States  San Francisco
# 4      Canva            $40   1/8/2018      Australia    Surry Hills
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors  year month
# 0  Sequoia Capital China, SIG Asia Investments, S...  2017     4
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...  2012    12
# 2  Tiger Global Management, Sequoia Capital China...  2018     7
# 3        Khosla Ventures, LowercaseCapital, capitalG  2014     1
# 4  Sequoia Capital China, Blackbird Ventures, Mat...  2018     1
